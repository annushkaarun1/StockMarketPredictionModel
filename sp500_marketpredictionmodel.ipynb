# %% [markdown]
# <a href="https://colab.research.google.com/github/annushkaarun1/StockMarketPredictionModel/blob/main/sp500_marketpredictionmodel.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import yfinance as yf

# %%
sp500 = yf.Ticker("^GSPC")

# %%
sp500 = sp500.history(period="max")

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-01-27 00:00:00-05:00  5969.040039  6017.169922  5962.919922  6012.279785
# 2025-01-28 00:00:00-05:00  6026.970215  6074.540039  5994.629883  6067.700195
# 2025-01-29 00:00:00-05:00  6057.700195  6062.830078  6012.959961  6039.310059
# 2025-01-30 00:00:00-05:00  6050.750000  6086.640137  6027.459961  6071.169922
# 2025-01-31 00:00:00-05:00  6096.790039  6120.910156  6030.930176  6040.529785
#
# ...

# %%
sp500.index
# Out:
# DatetimeIndex(['1927-12-30 00:00:00-05:00', '1928-01-03 00:00:00-05:00',
#                '1928-01-04 00:00:00-05:00', '1928-01-05 00:00:00-05:00',
#                '1928-01-06 00:00:00-05:00', '1928-01-09 00:00:00-05:00',
#                '1928-01-10 00:00:00-05:00', '1928-01-11 00:00:00-05:00',
#                '1928-01-12 00:00:00-05:00', '1928-01-13 00:00:00-05:00',
#                ...
#                '2025-01-17 00:00:00-05:00', '2025-01-21 00:00:00-05:00',
#                '2025-01-22 00:00:00-05:00', '2025-01-23 00:00:00-05:00',
#                '2025-01-24 00:00:00-05:00', '2025-01-27 00:00:00-05:00',
#                '2025-01-28 00:00:00-05:00', '2025-01-29 00:00:00-05:00',
#                '2025-01-30 00:00:00-05:00', '2025-01-31 00:00:00-05:00'],
#               dtype='datetime64[ns, America/New_York]', name='Date', length=24387, freq=None)

# %%
sp500.plot.line(y="Close", use_index=True)
# Out:
# <Axes: xlabel='Date'>

# %%
del sp500["Dividends"]
del sp500["Stock Splits"]

# %%
#predicting target - up or down
sp500["Tomorrow"] = sp500["Close"].shift(-1)

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1927-12-30 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# 1928-01-03 00:00:00-05:00    17.760000    17.760000    17.760000    17.760000
# 1928-01-04 00:00:00-05:00    17.719999    17.719999    17.719999    17.719999
# 1928-01-05 00:00:00-05:00    17.549999    17.549999    17.549999    17.549999
# 1928-01-06 00:00:00-05:00    17.660000    17.660000    17.660000    17.660000
# ...                                ...          ...          ...          ...
# 2025-01-27 00:00:00-05:00  5969.040039  6017.169922  5962.919922  6012.279785
# 2025-01-28 00:00:00-05:00  6026.970215  6074.540039  5994.629883  6067.700195
# 2025-01-29 00:00:00-05:00  6057.700195  6062.830078  6012.959961  6039.310059
# 2025-01-30 00:00:00-05:00  6050.750000  6086.640137  6027.459961  6071.169922
# 2025-01-31 00:00:00-05:00  6096.790039  6120.910156  6030.930176  6040.529785
#
# ...

# %%
sp500["Target"] = (sp500["Tomorrow"] > sp500["Close"]).astype(int)

# %%
sp500 = sp500.loc["1990-01-01":].copy()

# %%
#train initial ML model
from sklearn.ensemble import RandomForestClassifier
model = RandomForestClassifier(n_estimators=100, min_samples_split=100, random_state=1)

train = sp500.iloc[:-100]
test = sp500.iloc[-100:]

predictors = ["Close", "Volume", "Open", "High", "Low"]
model.fit(train[predictors], train["Target"])

#^ trains model using predictor columns
# Out:
# RandomForestClassifier(min_samples_split=100, random_state=1)

# %%
from sklearn.metrics import precision_score
import pandas as pd
#did it go up when we said it was gonna go up
# good error metric

preds = model.predict(test[predictors])
preds = pd.Series(preds, index=test.index)
precision_score(test["Target"], preds)
# Out:
# 1.0

# %%
combined = pd.concat([test["Target"], preds], axis = 1)
combined.plot()
# Out:
# <Axes: xlabel='Date'>

# %%
#building backtesting system
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"]) #fits model to generate predictions
    preds = model.predict(test[predictors])
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined

# %%
def backtest(data, model, predictors, start=2500, step=250):
    all_predictions = []

    for i in range(start, data.shape[0], step):
        train = data.iloc[0:i].copy()
        test = data.iloc[i:(i+step)].copy()
        predictions = predict(train, test, predictors, model)
        all_predictions.append(predictions)

    return pd.concat(all_predictions)

# %%
predictions = backtest(sp500, model, predictors)

# %%
predictions["Predictions"].value_counts()
# Out:
# Predictions
# 0    3702
# 1    2635
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.5286527514231499

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.536058
# 0    0.463942
# Name: count, dtype: float64

# %%
#adding additional predictors to the model
horizons = [2, 5, 60, 250, 1000]
new_predictors = []

for each in horizons:
    rolling_averages = sp500.rolling(each).mean()
    ratio_column = f"Close_Ratio_{each}"
    sp500[ratio_column] = sp500["Close"] / rolling_averages["Close"]

    trend_column = f"Trend_{each}"
    sp500[trend_column] = sp500.shift(1).rolling(each).sum()["Target"]

    new_predictors += [ratio_column, trend_column]

# %%
sp500 = sp500.dropna(subset=sp500.columns[sp500.columns != "Tomorrow"])

# %%
sp500
# Out:
#                                   Open         High          Low        Close  \
# Date
# 1993-12-14 00:00:00-05:00   465.730011   466.119995   462.459991   463.059998
# 1993-12-15 00:00:00-05:00   463.059998   463.690002   461.839996   461.839996
# 1993-12-16 00:00:00-05:00   461.859985   463.980011   461.859985   463.339996
# 1993-12-17 00:00:00-05:00   463.339996   466.380005   463.339996   466.380005
# 1993-12-20 00:00:00-05:00   466.380005   466.899994   465.529999   465.850006
# ...                                ...          ...          ...          ...
# 2025-01-27 00:00:00-05:00  5969.040039  6017.169922  5962.919922  6012.279785
# 2025-01-28 00:00:00-05:00  6026.970215  6074.540039  5994.629883  6067.700195
# 2025-01-29 00:00:00-05:00  6057.700195  6062.830078  6012.959961  6039.310059
# 2025-01-30 00:00:00-05:00  6050.750000  6086.640137  6027.459961  6071.169922
# 2025-01-31 00:00:00-05:00  6096.790039  6120.910156  6030.930176  6040.529785
#
# ...

# %%
#improve model
model = RandomForestClassifier(n_estimators=200, min_samples_split=500, random_state=1)

# %%
def predict(train, test, predictors, model):
    model.fit(train[predictors], train["Target"])
    preds = model.predict_proba(test[predictors])[:,1]
    preds[preds >= .6] = 1
    preds[preds < .6] = 0 #reduce number of days
    preds = pd.Series(preds, index=test.index, name="Predictions")
    combined = pd.concat([test["Target"], preds], axis=1)
    return combined
#

# %%
predictions = backtest(sp500, model, new_predictors)

# %%
predictions["Predictions"].value_counts()
#can see how results change after changing threshold
# Out:
# Predictions
# 0.0    5162
# 1.0     175
# Name: count, dtype: int64

# %%
precision_score(predictions["Target"], predictions["Predictions"])
# Out:
# 0.6228571428571429

# %%
predictions["Target"].value_counts() / predictions.shape[0]
# Out:
# Target
# 1    0.545625
# 0    0.454375
# Name: count, dtype: float64

# %%
predictions # final
# Out:
#                            Target  Predictions
# Date
# 2003-11-14 00:00:00-05:00       0          0.0
# 2003-11-17 00:00:00-05:00       0          0.0
# 2003-11-18 00:00:00-05:00       1          0.0
# 2003-11-19 00:00:00-05:00       0          0.0
# 2003-11-20 00:00:00-05:00       1          0.0
# ...                           ...          ...
# 2025-01-27 00:00:00-05:00       1          0.0
# 2025-01-28 00:00:00-05:00       0          0.0
# 2025-01-29 00:00:00-05:00       1          0.0
# 2025-01-30 00:00:00-05:00       0          0.0
# 2025-01-31 00:00:00-05:00       0          0.0
#
# [5337 rows x 2 columns]
